# %% [markdown]
# Mining local repository

# %%
#!/bin/bash

vulguard mining \
    -repo_name libssh2 \
    -repo_path test/test_repo \
    -mode local \
    -repo_language C \
    -szz vszz \
    -dg_save_folder . \
    -workers 10 \
    -start 1000 \
    -end 1200
